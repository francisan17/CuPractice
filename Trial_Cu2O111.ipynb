# %% [markdown]
# <a href="https://colab.research.google.com/github/francisan17/CuPractice/blob/main/Trial_Cu2O111.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install torch-dftd
# Out:
# Collecting torch-dftd
#   Downloading torch_dftd-0.4.0-py3-none-any.whl (681 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 681.4/681.4 kB 7.6 MB/s eta 0:00:00
# Collecting ase<4.0.0,>=3.18 (from torch-dftd)
#   Downloading ase-3.23.0-py3-none-any.whl (2.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 18.0 MB/s eta 0:00:00
# Collecting pymatgen>=2020.1.28 (from torch-dftd)
#   Downloading pymatgen-2024.6.10-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.8/4.8 MB 22.1 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.18.5 in /usr/local/lib/python3.10/dist-packages (from ase<4.0.0,>=3.18->torch-dftd) (1.25.2)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from ase<4.0.0,>=3.18->torch-dftd) (1.11.4)
# Requirement already satisfied: matplotlib>=3.3.4 in /usr/local/lib/python3.10/dist-packages (from ase<4.0.0,>=3.18->torch-dftd) (3.7.1)
# Collecting matplotlib>=3.3.4 (from ase<4.0.0,>=3.18->torch-dftd)
#   Downloading matplotlib-3.9.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (8.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.3/8.3 MB 51.2 MB/s eta 0:00:00
# Collecting monty>=2024.5.24 (from pymatgen>=2020.1.28->torch-dftd)
#   Downloading monty-2024.5.24-py3-none-any.whl (67 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.9/67.9 kB 9.8 MB/s eta 0:00:00
# Requirement already satisfied: networkx>=2.2 in /usr/local/lib/python3.10/dist-packages (from pymatgen>=2020.1.28->torch-dftd) (3.3)
# Collecting palettable>=3.1.1 (from pymatgen>=2020.1.28->torch-dftd)
#   Downloading palettable-3.3.3-py2.py3-none-any.whl (332 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 332.3/332.3 kB 33.2 MB/s eta 0:00:00
# Requirement already satisfied: pandas>=2 in /usr/local/lib/python3.10/dist-packages (from pymatgen>=2020.1.28->torch-dftd) (2.0.3)
# Requirement already satisfied: plotly>=4.5.0 in /usr/local/lib/python3.10/dist-packages (from pymatgen>=2020.1.28->torch-dftd) (5.15.0)
# Collecting pybtex>=0.24.0 (from pymatgen>=2020.1.28->torch-dftd)
#   Downloading pybtex-0.24.0-py2.py3-none-any.whl (561 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 561.4/561.4 kB 49.1 MB/s eta 0:00:00
# Collecting requests>=2.32 (from pymatgen>=2020.1.28->torch-dftd)
#   Downloading requests-2.32.3-py3-none-any.whl (64 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.9/64.9 kB 7.1 MB/s eta 0:00:00
# Collecting ruamel.yaml>=0.17.0 (from pymatgen>=2020.1.28->torch-dftd)
#   Downloading ruamel.yaml-0.18.6-py3-none-any.whl (117 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.8/117.8 kB 5.9 MB/s eta 0:00:00
# Collecting scipy>=1.6.0 (from ase<4.0.0,>=3.18->torch-dftd)
#   Downloading scipy-1.14.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (41.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.1/41.1 MB 16.4 MB/s eta 0:00:00
# Collecting spglib>=2.0.2 (from pymatgen>=2020.1.28->torch-dftd)
#   Downloading spglib-2.4.0-cp310-cp310-manylinux_2_17_x86_64.whl (809 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 809.2/809.2 kB 38.0 MB/s eta 0:00:00
# Requirement already satisfied: sympy>=1.2 in /usr/local/lib/python3.10/dist-packages (from pymatgen>=2020.1.28->torch-dftd) (1.12.1)
# Requirement already satisfied: tabulate>=0.9 in /usr/local/lib/python3.10/dist-packages (from pymatgen>=2020.1.28->torch-dftd) (0.9.0)
# Requirement already satisfied: tqdm>=4.60 in /usr/local/lib/python3.10/dist-packages (from pymatgen>=2020.1.28->torch-dftd) (4.66.4)
# Collecting uncertainties>=3.1.4 (from pymatgen>=2020.1.28->torch-dftd)
#   Downloading uncertainties-3.2.2-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 7.4 MB/s eta 0:00:00
# Requirement already satisfied: joblib>=1 in /usr/local/lib/python3.10/dist-packages (from pymatgen>=2020.1.28->torch-dftd) (1.4.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.4->ase<4.0.0,>=3.18->torch-dftd) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.4->ase<4.0.0,>=3.18->torch-dftd) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.4->ase<4.0.0,>=3.18->torch-dftd) (4.53.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.4->ase<4.0.0,>=3.18->torch-dftd) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.4->ase<4.0.0,>=3.18->torch-dftd) (24.1)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.4->ase<4.0.0,>=3.18->torch-dftd) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.4->ase<4.0.0,>=3.18->torch-dftd) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.4->ase<4.0.0,>=3.18->torch-dftd) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=2->pymatgen>=2020.1.28->torch-dftd) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=2->pymatgen>=2020.1.28->torch-dftd) (2024.1)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly>=4.5.0->pymatgen>=2020.1.28->torch-dftd) (8.4.2)
# Requirement already satisfied: PyYAML>=3.01 in /usr/local/lib/python3.10/dist-packages (from pybtex>=0.24.0->pymatgen>=2020.1.28->torch-dftd) (6.0.1)
# Collecting latexcodec>=1.0.4 (from pybtex>=0.24.0->pymatgen>=2020.1.28->torch-dftd)
#   Downloading latexcodec-3.0.0-py3-none-any.whl (18 kB)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from pybtex>=0.24.0->pymatgen>=2020.1.28->torch-dftd) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32->pymatgen>=2020.1.28->torch-dftd) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32->pymatgen>=2020.1.28->torch-dftd) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32->pymatgen>=2020.1.28->torch-dftd) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32->pymatgen>=2020.1.28->torch-dftd) (2024.6.2)
# Collecting ruamel.yaml.clib>=0.2.7 (from ruamel.yaml>=0.17.0->pymatgen>=2020.1.28->torch-dftd)
#   Downloading ruamel.yaml.clib-0.2.8-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_24_x86_64.whl (526 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 526.7/526.7 kB 41.3 MB/s eta 0:00:00
# Requirement already satisfied: mpmath<1.4.0,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy>=1.2->pymatgen>=2020.1.28->torch-dftd) (1.3.0)
# Installing collected packages: uncertainties, spglib, scipy, ruamel.yaml.clib, requests, palettable, monty, latexcodec, ruamel.yaml, pybtex, matplotlib, pymatgen, ase, torch-dftd
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.11.4
#     Uninstalling scipy-1.11.4:
#       Successfully uninstalled scipy-1.11.4
#   Attempting uninstall: requests
#     Found existing installation: requests 2.31.0
#     Uninstalling requests-2.31.0:
#       Successfully uninstalled requests-2.31.0
#   Attempting uninstall: matplotlib
#     Found existing installation: matplotlib 3.7.1
#     Uninstalling matplotlib-3.7.1:
#       Successfully uninstalled matplotlib-3.7.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires requests==2.31.0, but you have requests 2.32.3 which is incompatible.
# Successfully installed ase-3.23.0 latexcodec-3.0.0 matplotlib-3.9.1 monty-2024.5.24 palettable-3.3.3 pybtex-0.24.0 pymatgen-2024.6.10 requests-2.32.3 ruamel.yaml-0.18.6 ruamel.yaml.clib-0.2.8 scipy-1.14.0 spglib-2.4.0 torch-dftd-0.4.0 uncertainties-3.2.2

# %%
# !pip install mace-torch
# Out:
# Collecting mace-torch
#   Downloading mace_torch-0.3.5-py3-none-any.whl (115 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.3/115.3 kB 2.9 MB/s eta 0:00:00
# Requirement already satisfied: torch>=1.12 in /usr/local/lib/python3.10/dist-packages (from mace-torch) (2.3.0+cu121)
# Collecting e3nn==0.4.4 (from mace-torch)
#   Downloading e3nn-0.4.4-py3-none-any.whl (387 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 387.7/387.7 kB 7.7 MB/s eta 0:00:00
# Requirement already satisfied: numpy<2.0 in /usr/local/lib/python3.10/dist-packages (from mace-torch) (1.25.2)
# Requirement already satisfied: opt-einsum in /usr/local/lib/python3.10/dist-packages (from mace-torch) (3.3.0)
# Requirement already satisfied: ase in /usr/local/lib/python3.10/dist-packages (from mace-torch) (3.23.0)
# Collecting torch-ema (from mace-torch)
#   Downloading torch_ema-0.3-py3-none-any.whl (5.5 kB)
# Requirement already satisfied: prettytable in /usr/local/lib/python3.10/dist-packages (from mace-torch) (3.10.0)
# Collecting matscipy (from mace-torch)
#   Downloading matscipy-1.0.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (438 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 438.9/438.9 kB 9.6 MB/s eta 0:00:00
# Requirement already satisfied: h5py in /usr/local/lib/python3.10/dist-packages (from mace-torch) (3.9.0)
# Collecting torchmetrics (from mace-torch)
#   Downloading torchmetrics-1.4.0.post0-py3-none-any.whl (868 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 868.8/868.8 kB 14.0 MB/s eta 0:00:00
# Collecting python-hostlist (from mace-torch)
#   Downloading python-hostlist-1.23.0.tar.gz (36 kB)
#   Preparing metadata (setup.py) ... done
# Collecting configargparse (from mace-torch)
#   Downloading ConfigArgParse-1.7-py3-none-any.whl (25 kB)
# Collecting GitPython (from mace-torch)
#   Downloading GitPython-3.1.43-py3-none-any.whl (207 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.3/207.3 kB 9.3 MB/s eta 0:00:00
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from mace-torch) (4.66.4)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from mace-torch) (3.9.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from mace-torch) (2.0.3)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from e3nn==0.4.4->mace-torch) (1.12.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from e3nn==0.4.4->mace-torch) (1.14.0)
# Collecting opt-einsum-fx>=0.1.4 (from e3nn==0.4.4->mace-torch)
#   Downloading opt_einsum_fx-0.1.4-py3-none-any.whl (13 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.12->mace-torch) (3.15.4)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.12->mace-torch) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.12->mace-torch) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.12->mace-torch) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.12->mace-torch) (2023.6.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch>=1.12->mace-torch)
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch>=1.12->mace-torch)
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch>=1.12->mace-torch)
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# Collecting nvidia-cudnn-cu12==8.9.2.26 (from torch>=1.12->mace-torch)
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch>=1.12->mace-torch)
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch>=1.12->mace-torch)
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch>=1.12->mace-torch)
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch>=1.12->mace-torch)
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch>=1.12->mace-torch)
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# Collecting nvidia-nccl-cu12==2.20.5 (from torch>=1.12->mace-torch)
#   Using cached nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl (176.2 MB)
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch>=1.12->mace-torch)
#   Using cached nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
# Requirement already satisfied: triton==2.3.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.12->mace-torch) (2.3.0)
# Collecting nvidia-nvjitlink-cu12 (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.12->mace-torch)
#   Downloading nvidia_nvjitlink_cu12-12.5.82-py3-none-manylinux2014_x86_64.whl (21.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.3/21.3 MB 59.5 MB/s eta 0:00:00
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mace-torch) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mace-torch) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mace-torch) (4.53.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mace-torch) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mace-torch) (24.1)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mace-torch) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mace-torch) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mace-torch) (2.8.2)
# Collecting gitdb<5,>=4.0.1 (from GitPython->mace-torch)
#   Downloading gitdb-4.0.11-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 9.9 MB/s eta 0:00:00
# Collecting looseversion (from matscipy->mace-torch)
#   Downloading looseversion-1.3.0-py2.py3-none-any.whl (8.2 kB)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->mace-torch) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas->mace-torch) (2024.1)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from prettytable->mace-torch) (0.2.13)
# Collecting lightning-utilities>=0.8.0 (from torchmetrics->mace-torch)
#   Downloading lightning_utilities-0.11.3.post0-py3-none-any.whl (26 kB)
# Collecting smmap<6,>=3.0.1 (from gitdb<5,>=4.0.1->GitPython->mace-torch)
#   Downloading smmap-5.0.1-py3-none-any.whl (24 kB)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from lightning-utilities>=0.8.0->torchmetrics->mace-torch) (67.7.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->mace-torch) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.12->mace-torch) (2.1.5)
# Requirement already satisfied: mpmath<1.4.0,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->e3nn==0.4.4->mace-torch) (1.3.0)
# Building wheels for collected packages: python-hostlist
#   Building wheel for python-hostlist (setup.py) ... done
#   Created wheel for python-hostlist: filename=python_hostlist-1.23.0-py3-none-any.whl size=39722 sha256=e46e019e3a557893a226407bb290667a7e9cc01d5ebfb3cfbef7a68fa5e59d28
#   Stored in directory: /root/.cache/pip/wheels/5b/26/b1/e7045c42a5e45e08775e184db42f5e455cba62f906caa80ab1
# Successfully built python-hostlist
# Installing collected packages: python-hostlist, looseversion, smmap, nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, lightning-utilities, configargparse, nvidia-cusparse-cu12, nvidia-cudnn-cu12, gitdb, nvidia-cusolver-cu12, GitPython, matscipy, torchmetrics, torch-ema, opt-einsum-fx, e3nn, mace-torch
# Successfully installed GitPython-3.1.43 configargparse-1.7 e3nn-0.4.4 gitdb-4.0.11 lightning-utilities-0.11.3.post0 looseversion-1.3.0 mace-torch-0.3.5 matscipy-1.0.0 nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-8.9.2.26 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.20.5 nvidia-nvjitlink-cu12-12.5.82 nvidia-nvtx-cu12-12.1.105 opt-einsum-fx-0.1.4 python-hostlist-1.23.0 smmap-5.0.1 torch-ema-0.3 torchmetrics-1.4.0.post0

# %%
from ase import Atoms
from mace.calculators import mace_mp
from ase.build import surface
from ase.constraints import FixAtoms, UnitCellFilter
from ase.optimize import QuasiNewton
from ase.visualize import view
from ase.io import read, write
from ase.optimize import LBFGS
import numpy as np
import pandas as pd
from tabulate import tabulate
import tables
from cu2o_bulk_c import cu2o_bulk, cu2o111

bulk = cu2o_bulk()
bulk.calc = mace_mp(model="large", dispersion=True, default_dtype="float64", device='cuda')
ucf = UnitCellFilter(bulk)
LBFGS(ucf).run(fmax=0.01)
E_bulk = bulk.get_potential_energy()
bulk_oxygens = bulk[bulk.symbols=='O']
print(f"Number of Oxygen atoms in bulk: {len(bulk_oxygens)}")
#write('bulk.xyz', bulk)

n_layers = { 3,4,5,6,7,8,9,10}
Cu2Otable={}

n_layers_list=[]
slab_oxygens_list=[]
E_surf_list=[]

for n_layers in range(3,11):
  vacuum=10
  slab = cu2o111(bulk, n_layers, vacuum)
  #write('slab.xyz', slab)
  slab_oxygens = slab[slab.symbols=='O']
  Cu2Otable[n_layers]=len(slab_oxygens)
  print(f"Number of Oxygen atoms in slab: {len(slab_oxygens)}")

  slab.calc = mace_mp(model="large", dispersion=True, default_dtype="float64", device='cuda')
  E_slab = slab.get_potential_energy()
  E_cleav = (E_slab - E_bulk * n_layers) / 2 / np.linalg.det(slab.cell[:2, :2])
  print(f'{n_layers=} {E_cleav=}')

  qn = LBFGS(slab, trajectory='Cu2O111.traj')
  #write('Cu2O111.traj', slab)
  qn.run(fmax=0.01)
  E_slab = slab.get_potential_energy()
  #t = read('Cu2O111.traj')
  #view(t)

  ##Calc Surface Energy
  E_surf = (E_slab - E_bulk * n_layers) / 2 / np.linalg.det(slab.cell[:2, :2])
  print(f'{n_layers=} {E_surf=}')

  n_layers_list.append(n_layers)
  slab_oxygens_list.append(len(slab_oxygens))
  E_surf_list.append(E_surf)

df = pd.DataFrame({'Number of Layers': n_layers_list, 'Number of Oxygen Atoms':slab_oxygens_list, 'Surface Energy': E_surf_list})
table=tabulate(df, headers = 'keys', tablefmt = 'fancy_grid')
df.to_csv('Cu2O111.csv', index=False)
print(table)


#Fixing bottom layer, replicating bulk
#bottom_Cu_z = np.min(slab[slab.symbols=='Cu'].positions[:,2])
#mask1=slab.positions[:, 2] < bottom_Cu_z + 1.0
#slab.set_constraint(FixAtoms(mask=mask1))
# Out:
# Using Materials Project MACE for MACECalculator with /root/.cache/mace/5f5yavf3
# Using float64 for MACECalculator, which is slower but more accurate. Recommended for geometry optimization.
# Using TorchDFTD3Calculator for D3 dispersion corrections (see https://github.com/pfnet-research/torch-dftd)
# <ipython-input-5-e3250baff5c9>:17: FutureWarning: Import UnitCellFilter from ase.filters
#   ucf = UnitCellFilter(bulk)
#        Step     Time          Energy          fmax
# LBFGS:    0 13:21:29      -30.685465        0.329906
# LBFGS:    1 13:21:30      -30.690012        0.313324
# LBFGS:    2 13:21:30      -30.727313        0.056428
# LBFGS:    3 13:21:30      -30.728281        0.007799
# Number of Oxygen atoms in bulk: 2
# Number of Oxygen atoms in slab: 6
# Using Materials Project MACE for MACECalculator with /root/.cache/mace/5f5yavf3
# Using float64 for MACECalculator, which is slower but more accurate. Recommended for geometry optimization.
# Using TorchDFTD3Calculator for D3 dispersion corrections (see https://github.com/pfnet-research/torch-dftd)
# LBFGS:   20 13:22:28     -238.345111        0.029059
# LBFGS:   21 13:22:28     -238.345287        0.034810
# LBFGS:   22 13:22:29     -238.345492        0.042609
# LBFGS:   23 13:22:29     -238.345781        0.043965
# LBFGS:   24 13:22:29     -238.346062        0.028725
# LBFGS:   25 13:22:30     -238.346205        0.015441
# LBFGS:   26 13:22:30     -238.346249        0.012425
# LBFGS:   27 13:22:30     -238.346275        0.010595
# LBFGS:   28 13:22:31     -238.346315        0.012999
# LBFGS:   29 13:22:31     -238.346370        0.015066
# LBFGS:   30 13:22:31     -238.346427        0.012535
# LBFGS:   31 13:22:32     -238.346472        0.014453
# LBFGS:   32 13:22:32     -238.346507        0.013676
# LBFGS:   33 13:22:32     -238.346542        0.012080
# LBFGS:   34 13:22:33     -238.346573        0.009858
# n_layers=8 E_surf=0.12108414942120173
# Number of Oxygen atoms in slab: 18
# Using Materials Project MACE for MACECalculator with /root/.cache/mace/5f5yavf3
# Using float64 for MACECalculator, which is slower but more accurate. Recommended for geometry optimization.
# Using TorchDFTD3Calculator for D3 dispersion corrections (see https://github.com/pfnet-research/torch-dftd)
# n_layers=9 E_cleav=0.06760501172569629
#        Step     Time          Energy          fmax
# LBFGS:    0 13:22:33     -272.378398        1.197203
# LBFGS:    1 13:22:34     -272.428772        0.803130
# LBFGS:    2 13:22:34     -272.487463        0.272796
# LBFGS:    3 13:22:34     -272.501103        0.281186
# LBFGS:    4 13:22:35     -272.516345        0.379929
# LBFGS:    5 13:22:35     -272.527006        0.378292
# LBFGS:    6 13:22:36     -272.536934        0.290517
# LBFGS:    7 13:22:36     -272.546108        0.224133
# LBFGS:    8 13:22:36     -272.552156        0.226799
# LBFGS:    9 13:22:37     -272.555169        0.154638
# LBFGS:   10 13:22:37     -272.556959        0.112463
# LBFGS:   11 13:22:37     -272.558303        0.113252
# LBFGS:   12 13:22:38     -272.560083        0.119424
# LBFGS:   13 13:22:38     -272.561482        0.077695
# LBFGS:   14 13:22:38     -272.562358        0.093219
# LBFGS:   15 13:22:39     -272.563118        0.087411
# LBFGS:   16 13:22:39     -272.564053        0.076014
# LBFGS:   17 13:22:40     -272.564902        0.067363
# LBFGS:   18 13:22:40     -272.565394        0.044307
# LBFGS:   19 13:22:41     -272.565610        0.043814
# LBFGS:   20 13:22:41     -272.565812        0.055427
# LBFGS:   21 13:22:41     -272.566154        0.058129
# LBFGS:   22 13:22:42     -272.566590        0.043125
# LBFGS:   23 13:22:42     -272.566965        0.032883
# LBFGS:   24 13:22:42     -272.567174        0.028894
# LBFGS:   25 13:22:43     -272.567292        0.023462
# LBFGS:   26 13:22:43     -272.567396        0.020652
# LBFGS:   27 13:22:43     -272.567496        0.014720
# LBFGS:   28 13:22:44     -272.567579        0.016131
# LBFGS:   29 13:22:44     -272.567664        0.019391
# LBFGS:   30 13:22:45     -272.567778        0.030132
# LBFGS:   31 13:22:45     -272.567953        0.043185
# LBFGS:   32 13:22:45     -272.568165        0.042438
# LBFGS:   33 13:22:46     -272.568322        0.024304
# LBFGS:   34 13:22:46     -272.568384        0.011562
# LBFGS:   35 13:22:46     -272.568406        0.007762
# n_layers=9 E_surf=0.06452908100200179
# Number of Oxygen atoms in slab: 20
# Using Materials Project MACE for MACECalculator with /root/.cache/mace/5f5yavf3
# Using float64 for MACECalculator, which is slower but more accurate. Recommended for geometry optimization.
# Using TorchDFTD3Calculator for D3 dispersion corrections (see https://github.com/pfnet-research/torch-dftd)
# n_layers=10 E_cleav=0.06760497036036936
#        Step     Time          Energy          fmax
# LBFGS:    0 13:22:47     -303.106682        1.197203
# LBFGS:    1 13:22:48     -303.157056        0.803129
# LBFGS:    2 13:22:48     -303.215748        0.272798
# LBFGS:    3 13:22:48     -303.229391        0.281189
# LBFGS:    4 13:22:49     -303.244634        0.379934
# LBFGS:    5 13:22:49     -303.255295        0.378300
# LBFGS:    6 13:22:50     -303.265224        0.290524
# LBFGS:    7 13:22:50     -303.274401        0.224178
# LBFGS:    8 13:22:50     -303.280453        0.226872
# LBFGS:    9 13:22:51     -303.283470        0.154706
# LBFGS:   10 13:22:51     -303.285266        0.112565
# LBFGS:   11 13:22:52     -303.286618        0.113588
# LBFGS:   12 13:22:52     -303.288410        0.120044
# LBFGS:   13 13:22:52     -303.289832        0.078551
# LBFGS:   14 13:22:53     -303.290734        0.094378
# LBFGS:   15 13:22:53     -303.291509        0.088599
# LBFGS:   16 13:22:54     -303.292460        0.076754
# LBFGS:   17 13:22:54     -303.293320        0.067833
# LBFGS:   18 13:22:55     -303.293811        0.044585
# LBFGS:   19 13:22:55     -303.294021        0.043444
# LBFGS:   20 13:22:55     -303.294214        0.054470
# LBFGS:   21 13:22:56     -303.294540        0.056435
# LBFGS:   22 13:22:56     -303.294946        0.040976
# LBFGS:   23 13:22:57     -303.295289        0.030204
# LBFGS:   24 13:22:57     -303.295475        0.025207
# LBFGS:   25 13:22:57     -303.295582        0.021299
# LBFGS:   26 13:22:58     -303.295680        0.018662
# LBFGS:   27 13:22:58     -303.295780        0.015001
# LBFGS:   28 13:22:59     -303.295867        0.015810
# LBFGS:   29 13:22:59     -303.295957        0.020914
# LBFGS:   30 13:22:59     -303.296085        0.029970
# LBFGS:   31 13:23:00     -303.296288        0.045638
# LBFGS:   32 13:23:00     -303.296557        0.048472
# LBFGS:   33 13:23:01     -303.296780        0.030887
# LBFGS:   34 13:23:01     -303.296878        0.012082
# LBFGS:   35 13:23:01     -303.296908        0.008034
# n_layers=10 E_surf=0.06452550140355047
# ╒════╤════════════════════╤══════════════════════════╤══════════════════╕
# │    │   Number of Layers │   Number of Oxygen Atoms │   Surface Energy │
# ╞════╪════════════════════╪══════════════════════════╪══════════════════╡
# │  0 │                  3 │                        6 │        0.0643178 │
# ├────┼────────────────────┼──────────────────────────┼──────────────────┤
# │  1 │                  4 │                        8 │        0.120828  │
# ├────┼────────────────────┼──────────────────────────┼──────────────────┤
# │  2 │                  5 │                       10 │        0.106793  │
# ├────┼────────────────────┼──────────────────────────┼──────────────────┤
# │  3 │                  6 │                       12 │        0.0644832 │
# ├────┼────────────────────┼──────────────────────────┼──────────────────┤
# │  4 │                  7 │                       14 │        0.0645054 │
# ├────┼────────────────────┼──────────────────────────┼──────────────────┤
# │  5 │                  8 │                       16 │        0.121084  │
# ├────┼────────────────────┼──────────────────────────┼──────────────────┤
# │  6 │                  9 │                       18 │        0.0645291 │
# ├────┼────────────────────┼──────────────────────────┼──────────────────┤
# │  7 │                 10 │                       20 │        0.0645255 │
# ╘════╧════════════════════╧══════════════════════════╧══════════════════╛
